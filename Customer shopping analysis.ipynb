# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\\Users\\mythi\\Downloads\\Customer shopping Details.csv')

# %%
df.head()
# Out:
#   Customer ID   Customer Name  Age  Gender Item Purchased     Category  \
# 0   CUST00001      Riya Kumar   56    Male      Lip Gloss       Makeup
# 1   CUST00002   Lakshmi Kumar   57  Female        Handbag  Accessories
# 2   CUST00003    Aditya Mehta   54    Male       Sweaters     Clothing
# 3   CUST00004  Reyansh Pillai   70    Male    Moisturizer    Cosmetics
# 4   CUST00005    Suresh Singh   31    Male      Lip Gloss       Makeup
#
#    Purchase Amount (USD)   Location       Size     Colour  Season  \
# 0                  10.58  Bengaluru  Free Size  Navy Blue  Spring
# 1                  91.68    Chennai  Free Size  Navy Blue  Autumn
# 2                  87.98      Surat         XS     Maroon  Autumn
# 3                  29.39    Madurai  Free Size      Brown  Autumn
# 4                  32.38     Mumbai  Free Size       Blue  Autumn
#
#    Review Rating Subscription Status Shipping Type Discount Applied  \
# 0            1.1                 Yes  Store Pickup               No
# 1            2.1                 Yes      Next-Day              Yes
# 2            3.3                  No      Standard               No
# 3            1.8                 Yes      Standard               No
# 4            2.6                 Yes  Store Pickup               No
#
#   Promo Code  Previous Purchase Count    Payment Method Frequency of Purchases
# 0   No Promo                       35        Debit Card                 Rarely
# 1    NEWUSER                        6               UPI                Monthly
# 2   No Promo                       49               UPI                 Weekly
# 3   No Promo                       10  Cash on Delivery                 Rarely
# 4   No Promo                       20        Debit Card                 Rarely

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer ID              1000 non-null   object
#  1   Customer Name            1000 non-null   object
#  2   Age                      1000 non-null   int64
#  3   Gender                   1000 non-null   object
#  4   Item Purchased           1000 non-null   object
#  5   Category                 1000 non-null   object
#  6   Purchase Amount (USD)    1000 non-null   float64
#  7   Location                 1000 non-null   object
#  8   Size                     1000 non-null   object
#  9   Colour                   1000 non-null   object
#  10  Season                   1000 non-null   object
#  11  Review Rating            1000 non-null   float64
#  12  Subscription Status      1000 non-null   object
#  13  Shipping Type            1000 non-null   object
#  14  Discount Applied         1000 non-null   object
#  15  Promo Code               1000 non-null   object
#  16  Previous Purchase Count  1000 non-null   int64
#  17  Payment Method           1000 non-null   object
#  18  Frequency of Purchases   1000 non-null   object
# dtypes: float64(2), int64(2), object(15)
# memory usage: 148.6+ KB

# %%
df.describe(include='all')
# Out:
#        Customer ID Customer Name          Age  Gender  Item Purchased  \
# count         1000          1000  1000.000000    1000            1000
# unique        1000           556          NaN       3              34
# top      CUST00001  Ayaan Pillai          NaN  Female  Compact Powder
# freq             1             5          NaN     521              41
# mean           NaN           NaN    42.796000     NaN             NaN
# std            NaN           NaN    15.693778     NaN             NaN
# min            NaN           NaN    16.000000     NaN             NaN
# 25%            NaN           NaN    28.750000     NaN             NaN
# 50%            NaN           NaN    44.000000     NaN             NaN
# 75%            NaN           NaN    56.000000     NaN             NaN
# max            NaN           NaN    70.000000     NaN             NaN
#
#         Category  Purchase Amount (USD)   Location       Size Colour  Season  \
# count       1000            1000.000000       1000       1000   1000    1000
# unique         5                    NaN         20         13     17       4
# top     Clothing                    NaN  Hyderabad  Free Size  Green  Autumn
# freq         280                    NaN         60        534     70     295
# mean         NaN              49.283560        NaN        NaN    NaN     NaN
# std          NaN              31.677409        NaN        NaN    NaN     NaN
# min          NaN               4.900000        NaN        NaN    NaN     NaN
# 25%          NaN              24.895000        NaN        NaN    NaN     NaN
# 50%          NaN              41.010000        NaN        NaN    NaN     NaN
# 75%          NaN              68.725000        NaN        NaN    NaN     NaN
# max          NaN             149.690000        NaN        NaN    NaN     NaN
#
#         Review Rating Subscription Status  Shipping Type Discount Applied  \
# count     1000.000000                1000           1000             1000
# unique            NaN                   2              5                2
# top               NaN                  No  Free Shipping               No
# freq              NaN                 685            221              586
# mean         3.022300                 NaN            NaN              NaN
# std          1.141585                 NaN            NaN              NaN
# min          1.000000                 NaN            NaN              NaN
# 25%          2.100000                 NaN            NaN              NaN
# 50%          3.000000                 NaN            NaN              NaN
# 75%          4.000000                 NaN            NaN              NaN
# max          5.000000                 NaN            NaN              NaN
#
#        Promo Code  Previous Purchase Count Payment Method  \
# count        1000              1000.000000           1000
# unique          7                      NaN              6
# top      No Promo                      NaN    Net Banking
# freq          647                      NaN            178
# mean          NaN                24.366000            NaN
# std           NaN                14.886627            NaN
# min           NaN                 0.000000            NaN
# 25%           NaN                11.000000            NaN
# 50%           NaN                23.000000            NaN
# 75%           NaN                37.000000            NaN
# max           NaN                50.000000            NaN
#
#        Frequency of Purchases
# count                    1000
# unique                      6
# top                    Rarely
# freq                      185
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Customer Name              0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Colour                     0
# Season                     0
# Review Rating              0
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code                 0
# Previous Purchase Count    0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'customer_name', 'age', 'gender', 'item_purchased',
#        'category', 'purchase_amount', 'location', 'size', 'colour', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code', 'previous_purchase_count',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
# create a column age_group
labels = ['Young Adult','Adult',' Middle-aged', 'Senior']
df['age_group'] = pd.qcut(df['age'], q=4,labels = labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age     age_group
# 0   56   Middle-aged
# 1   57        Senior
# 2   54   Middle-aged
# 3   70        Senior
# 4   31         Adult
# 5   47   Middle-aged
# 6   25   Young Adult
# 7   64        Senior
# 8   25   Young Adult
# 9   62        Senior

# %%
df[['discount_applied','promo_code']].head(10)
# Out:
#   discount_applied promo_code
# 0               No   No Promo
# 1              Yes    NEWUSER
# 2               No   No Promo
# 3               No   No Promo
# 4               No   No Promo
# 5               No   No Promo
# 6               No   No Promo
# 7               No   No Promo
# 8              Yes     SAVE20
# 9               No   No Promo

# %%
(df['discount_applied'] == df['promo_code']).all()
# Out:
# np.False_

# %%
df = df.drop('promo_code', axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'customer_name', 'age', 'gender', 'item_purchased',
#        'category', 'purchase_amount', 'location', 'size', 'colour', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchase_count', 'payment_method',
#        'frequency_of_purchases', 'age_group'],
#       dtype='object')

# %%
pip install sqlalchemy pymysql
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\mythi\anaconda3\lib\site-packages (2.0.43)
# Collecting pymysql
#   Downloading pymysql-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: greenlet>=1 in c:\users\mythi\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\mythi\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading pymysql-1.2.0-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:@localhost:3306/Customer_shopping_db')

# %%
# Database create பண்ணுங்க
conn = pymysql.connect(host='localhost', user='root', password='Mythili2006')
cursor = conn.cursor()
cursor.execute("CREATE DATABASE IF NOT EXISTS customer_shopping_db")
conn.close()
print("Database created!")
# Out:
# Database created!
